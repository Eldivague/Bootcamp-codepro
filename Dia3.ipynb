# %%
print('phbhbepe')
# Out:
# phbhbepe

# %%
# challenge 1

palabra = ('escribe una palabra')

def Imprimir_palabra():
    print(palabra)

Imprimir_palabra()
# Out:
# escribe una palabra

# %%
# challenge 2

numero1 = int(input('elige un numero'))
numero2 = int(input('elige otro numero'))

def suma_de_numeros(n1,n2):
    resultado_de_la_suma = (n1 + n2)
    print(resultado_de_la_suma)

suma_de_numeros(numero1 , numero2)
# Out:
# None

# %%
# challenge 2.1

letra1 = input('Escriba una letra')
letra2 = input('Escriba otra letra')

def letras_iguales_o_no(l1,l2):

    if l1 == l2:
        print('las letras son iguales')
    else:
        print('las letras son diferentes')

letras_iguales_o_no(letra1, letra2)
# Out:
# las letras son iguales

# %%
# challenge 3

# funcion
    # input palabra
    # input numero

palabra1 = input('Escribe una palabra')
numero_de_letras = int(input('escribe un numero'))

def Palabra_y_numero(Palabra, cantidad_de_letras):
    if len(Palabra) == cantidad_de_letras:
        return True
    else:
        return False

print(Palabra_y_numero(palabra1, numero_de_letras))
# Out:
# False

# %%
# challenge 4

palabra10 = input('Elige una palabra')
letra10 = input('escribe una letra')

def Contiene_letras_o_no(Palabra,letra):
    if letra in Palabra:
        return print([letra])
    else:
        return letra

Contiene_letras_o_no(palabra10, letra10)
# Out:
# 'o'

# %%
# challenge 5 

# primera_palabra = input('ingrese la primera palabra')

# Lista_de_palabras = list(primera_palabra)

# print(Lista_de_palabras)

# segunda_palabra = input('ingrese otra palabra')

# segunda_palabra_ingresada = list(segunda_palabra)

# Lista_de_palabras.append(segunda_palabra_ingresada)

# print(Lista_de_palabras)

# tercera_palabra = input('ingrese una ultima palabra')

# tercera_palabra_ingresada = list(tercera_palabra)

# Lista_de_palabras.append(tercera_palabra_ingresada)

# print(Lista_de_palabras)
# Out:
# ['o', 'l', 'a']
# ['o', 'l', 'a', ['y', 'o']]
# ['o', 'l', 'a', ['y', 'o'], ['m', 'e', 'l', 'l', 'a', 'm', 'o']]

# %%
#challenge 6

Listas_de_palabras = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]

def Crear_lista_de_listas(Listas_de_listas):
    for Listas in Listas_de_palabras:
        if len(Listas):
            print(Listas)

Crear_lista_de_listas(Listas_de_palabras)
# Out:
# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'a', 'l', 'l', 'o']

# %%
letras_verificadas = []
cantidad_letras = 5

def verificador_palabra(palabra_ingresada, palabra_secreta):
    for i in range(cantidad_letras):
        las_palabras_son_iguales = palabra_ingresada[i] == palabra_secreta[i] # True o False
        la_letra_existe_en_la_palabra = palabra_ingresada[i] in palabra_secreta 
        
        if las_palabras_son_iguales:
            letras_verificadas.append(f"[{palabra_ingresada[i]}]")
        elif la_letra_existe_en_la_palabra:
            letras_verificadas.append(f"({palabra_ingresada[i]})")
        else:
            letras_verificadas.append(palabra_ingresada[i])
    
    return letras_verificadas

verificador_palabra('holas', 'calor')
# Out:
# ['h', '(o)', '[l]', '(a)', 's']

# %%
while intentos < 6:
    print(f"te quedan {6 - intentos} intentos")
    intentos = intentos + 1
    palabra_ingresada = input("Ingrese una palabra")
    for palabras in letras_verificadas:
        if len(palabras):
            print(palabras)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 while intentos < 6:
#       2     print(f"te quedan {6 - intentos} intentos")
#       3     intentos = intentos + 1
#
# NameError: name 'intentos' is not defined
