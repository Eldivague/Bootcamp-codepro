# %%
print('hola mundo')
# Out:
# hola mundo

# %%
# Challenge 1

nombre = 'Eduardo'
ciudad = 'Limpio'
edad = 19

print(nombre, ciudad, edad)
# Out:
# Eduardo Limpio 19

# %%
# challenge 2

# variables frutas

Cantidad_de_manzanas = 25
Cantidad_de_naranjas = 15

# Suma de cantidad de frutas
Cantidad_de_fruras = Cantidad_de_manzanas+Cantidad_de_naranjas

print('las frutas en total son', Cantidad_de_fruras)

# Ventas de frutas

Frutas_vendidas = 20

print('las frutas vendidas son', Frutas_vendidas)

Frutas_restantes = Cantidad_de_fruras-Frutas_vendidas

print('las frutas que quedan son', Frutas_restantes)
# Out:
# las frutas en total son 40
# las frutas vendidas son 20
# las frutas que quedan son 20

# %%
# challenge 3

# nombre y apellido

Nombre = 'Marcelo'
Apellido = 'Paniagua'

print(f'Hola. me llamo {Nombre} {Apellido} mucho gusto.')
# Out:
# Hola. me llamo Marcelo Paniagua mucho gusto.

# %%
# challenge 4

Mandarinas_guardadas = int(input('Mandarinas guardadas'))
Sandias_guardadas = int(input('Sandias guardadas'))


Total_de_frutas = Mandarinas_guardadas + Sandias_guardadas

print(f'el total de frutas es {Total_de_frutas}')
# Out:
# el total de frutas es 46

# %%
# challenge 5

# definir la funcion
def extender_la_cama():
    print('extendiendo la sabana')
    print('acomodando las almohadas')
    print('listo para hacer noni')
    print(' ')

# realizar la funcion

extender_la_cama()
extender_la_cama()
extender_la_cama()
# Out:
# extendiendo la sabana
# acomodando las almohadas
# listo para hacer noni
#
# extendiendo la sabana
# acomodando las almohadas
# listo para hacer noni
#
# extendiendo la sabana
# acomodando las almohadas
# listo para hacer noni

# %%
# challenge 6

# realizar la funcion
def telefono_en_venta (x,y):
    print(f'el telefono lleva {x} de espacio y pesa {y}')

# Caracteristicas del telefono

Almacenamiento = input('Alacenamiento del telefono')
Peso_del_telefono = input('Peso del telefono')


# llamar a la funcion
telefono_en_venta(Almacenamiento,Peso_del_telefono)
# Out:
# el telefono lleva 500gb de espacio y pesa 800g

# %%
# challenge 7

# realizar la funcion
def auto_para_comprar(color, modelo, anho):

    color = input('Que color te gustaria el auto')
    modelo = input('que modelo seria')
    anho = input('que anho seria')

    print(f'El vehiculo seria de color {color} seria del modelo {modelo} y del anho {anho}')

          


auto_para_comprar(color, modelo, anho)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 15
#       8     anho = input('que anho seria')
#      10     print(f'El vehiculo seria de color {color} seria del modelo {modelo} y del anho {anho}')
# ---> 15 auto_para_comprar()
#
# TypeError: auto_para_comprar() missing 3 required positional arguments: 'color', 'modelo', and 'anho'
